# %% [markdown]
# # CS699 Web Crawler - Report
#
# This is a python project to crawl and scrape restaurant data from [Yelp.com](https://www.yelp.com/madison).
#
# ## Running the Spider
#
# This project uses the [Scrapy framework](https://scrapy.org/) for running the crawler. The crawler is invoked using the scrapy command as follows:
#
# ```bash
# # Command Line Flags
# # -o output file name
# # -t format of output file
# scrapy crawl yelp -o restaurant.csv -t csv
# ```
#
# ## Implementation Notes
#
# We chose to crawl Yelp.com due to it's relaxed rules around web crawling. While domains like Zomato.com and GrubHub.com aggressively block crawlers and instead encourage the use of their APIs, Yelp.com isn't as effective in blocking crawlers. To avoid being blocked by Yelp.com, we configured the crawler (see [settings.py](https://github.com/shantanusinghal/mad-repo/blob/master/cs699-python/Breakfast/settings.py)) to request pages at a slow (human like) pace and not make any concurrent requests.
#
# We've written the python code in an Object Oriented manner with domain entities such as [`YelpSpider`](https://github.com/shantanusinghal/mad-repo/blob/master/cs699-python/Breakfast/spiders/yelp.py#L6) and [`YelpListing`](https://github.com/shantanusinghal/mad-repo/blob/master/cs699-python/Breakfast/items.py#L18). The `YelpSpider` starts at the search results page and collects the links for individual restaurant pages that are asynchronously crawled by [`parse_listing_page`](https://github.com/shantanusinghal/mad-repo/blob/master/cs699-python/Breakfast/spiders/yelp.py#L25) function. For each listing page the we build a `YelpListing` instance, that encapsulates all the attributes associated with that web-page. We've used XPath and CSS selectors to extract this data from the HTML body.
#
# ## Extracted data
#
# The extracted data is stored in a CSV file and looks like this sample:
#
# ```bash
# reviews,rating,price_to,title,price_from,address,phone_number,categories
# 282,4,30,Short Stack Eatery,11,"301 W Johnson St Madison, WI 53703",(608) 709-5569,["Breakfast & Brunch"]
# ```
#
# ## Visualizing data
#
# In the following cells, we try to visualize the data to gain some insight into the underlying data distribution. We'll used pandas library to read the data from disk and numpy for various data manipulation and transformation tasks.
#
# * Fig 1 - Each bar denotes the average price of restaurants in that category and the error bars highlight the standard deviation in prices within the category. Looking at this plot, it is easy to identify 'Lounges' and 'Juice Bars' as two categories with generally poorly rated establishments.
# * Fig 2 - Shows the relationship between ratings, number of reviews and prices at these restaurants. Looking at the plot it's fair to say that neither the number of reviews nor the price point is a good indicator of the rating. This would imply that we need to collect more/different data about each restaurant before we can start predicting it's ratings.

# %%
# import all required libraries
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import pandas as pd
import math
from plotly.graph_objs import *
from plotly.graph_objs import ColorBar

# set the credentials to access the Plotly API
#plotly.tools.set_credentials_file(username='shantanusinghal', api_key='*********')

# read the data collected from web scrapping
df = pd.read_csv('breakfast_yelp.csv', encoding='latin1')
df
# Out:
#     reviews  rating  price_to                             title  price_from  \
# 0        88     4.5        10       Pat OÛªMalleyÛªs Jet Room           0
# 1       135     4.5        10                4&20 Bakery & Cafe           0
# 2        51     4.5        10                      Cottage Cafe           0
# 3       351     4.0        30        Bassett Street Brunch Club          11
# 4       246     4.0        30                    Eldorado Grill          11
# 5       253     4.0        10                 Mickies Dairy Bar           0
# 6       146     4.0        10                        Crema Cafe           0
# 7       282     4.0        30                Short Stack Eatery          11
# 8       226     4.0        10                     Lazy JaneÛªs           0
# 9       141     3.5        30                     Gates & Brovi          11
# 10      454     4.0        30                  Marigold Kitchen          11
# 11       14     4.0        30                              CIRC          11
# 12      146     4.0        30           OliverÛªs Public House          11
# 13      290     3.5        30                    Cafe Hollander          11
# 14      339     4.0        30                              DLUX          11
# 15       21     4.0        10                            Porter           0
# 16      211     4.0        60                             Cento          31
# 17       66     4.0        30                            Everly          11
# 18       42     4.0        10           Vintage Spirits & Grill           0
# 19      125     4.0        30            Original Pancake House          11
# 20      222     4.0        30            Daisy Cafe & Cupcakery          11
# 21       70     3.5        30                DobhanÛªs Kitchen          11
# 22       89     4.0        30         The Waypoint Public House          11
# 23      143     3.5        10                      Sunroom Cafe           0
# 24       66     4.0        10                 WillalbyÛªs Cafe           0
# 25      134     4.0        10              Johnson Public House           0
# 26       78     4.0        10                     Plaka Taverna           0
# 27       30     3.0        30                          The Wise          11
# 28       55     4.0        10             Helbachs Coffee House           0
# 29      187     4.5        10          SophiaÛªs Bakery & Cafe           0
# ..      ...     ...       ...                               ...         ...
# 59       24     3.5        30             Prairie Cafe & Bakery          11
# 60        7     4.0        10                      Village Cafe           0
# 61        2     2.5        60                     Badger Market          31
# 62       41     2.5        30                      Pancake Cafe          11
# 63       17     3.0        10                         DennyÛªs           0
# 64       18     4.0        10            Olde Town Coffee House           0
# 65       21     2.0        10                              IHOP           0
# 66       19     3.0        10               BrueggerÛªs Bagels           0
# 67       13     3.0        10                            Treads           0
# 68        6     2.5        30                      Olive Lounge          11
# 69       10     4.0        10    Green Forest Family Restaurant           0
# 70       26     2.5        10                              IHOP           0
# 71       47     4.5        10               Firefly Coffeehouse           0
# 72       26     3.5        30            Maple Tree Supper Club          11
# 73       14     2.5        10                         DennyÛªs           0
# 74       20     3.5        10                      Country Cafe           0
# 75       16     3.5        10    LeystraÛªs Venture Restaurant           0
# 76        6     3.0        10                  Big Apple Bagels           0
# 77       42     4.0        30         RayÛªs Family Restaurant          11
# 78        2     4.5        10               MaryÛªs Scone Shop           0
# 79       41     3.5        30              FitzÛªs On The Lake          11
# 80       14     4.0        10  WhatÛªs BrewÛªn In Sun Prairie           0
# 81       69     4.0        30                   Blue Spoon Cafe          11
# 82       68     4.5        30                      Cow & Quince          11
# 83        3     2.5        10    Cross Plains Family Restaurant           0
# 84      110     3.0        30                      Pancake Cafe          11
# 85       37     4.0        30  SchubertÛªs Downtown Restaurant          11
# 86       37     4.0        10              True Coffee Roasters           0
# 87       19     3.0        30                    CoachÛªs Club          11
# 88       13     4.0        10            Ancora Coffee Roasters           0
#
#                                               address    phone_number  \
# 0                    3606 Corben Ct Madison, WI 53704  (608) 268-5010
# 1                      305 N 4th St Madison, WI 53704  (608) 819-8893
# 2                     915 Atlas Ave Madison, WI 53714  (608) 221-4815
# 3                  444 W Johnson St Madison, WI 53703  (608) 467-5051
# 4                 744 Williamson St Madison, WI 53703  (608) 280-9378
# 5                    1511 Monroe St Madison, WI 53711  (608) 256-9476
# 6                    4124 Monona Dr Madison, WI 53716  (608) 224-1150
# 7                  301 W Johnson St Madison, WI 53703  (608) 709-5569
# 8                1358 Williamson St Madison, WI 53703  (608) 257-5263
# 9                    3502 Monroe St Madison, WI 53711  (608) 819-8988
# 10                118 S Pinckney St Madison, WI 53703  (608) 661-5559
# 11  1 W Dayton St The Madison Concourse Hotel And ...  (608) 294-3031
# 12              2540 University Ave Madison, WI 53705  (608) 819-8555
# 13               726 N Midvale Blvd Madison, WI 53705  (608) 237-3168
# 14   117 Martin Luther King Jr Blvd Madison, WI 53703  (608) 467-3130
# 15     640 W Washington Ave Ste 101 Madison, WI 53703  (608) 720-1110
# 16                 122 W Mifflin St Madison, WI 53703  (608) 284-9378
# 17           2701 Monroe St Ste 270 Madison, WI 53711  (608) 416-5242
# 18               529 University Ave Madison, WI 53703  (608) 250-0700
# 19              5518 University Ave Madison, WI 53705  (608) 231-3666
# 20                  2827 Atwood Ave Madison, WI 53704  (608) 241-2200
# 21                  2110 Atwood Ave Madison, WI 53704  (608) 242-4448
# 22                    320 W Broadway Monona, WI 53716  (608) 222-0224
# 23                     638 State St Madison, WI 53703  (608) 255-1555
# 24               1351 Williamson St Madison, WI 53703  (608) 259-9032
# 25                 908 E Johnson St Madison, WI 53703  (608) 347-0483
# 26                  410 E Wilson St Madison, WI 53774  (608) 251-4455
# 27                   1501 Monroe St Madison, WI 53711  (608) 819-8230
# 28                  410 Donofrio Dr Madison, WI 53719  (608) 821-0571
# 29           831 E Johnson St Ste 4 Madison, WI 53703  (608) 259-1506
# ..                                                ...             ...
# 59        3109 Pheasant Branch Rd Middleton, WI 53562  (608) 827-2437
# 60     214 W Cottage Grove Rd Cottage Grove, WI 53527  (608) 839-4141
# 61  1300 University Ave Medical Sciences Madison, ...  (608) 263-1166
# 62                  724 S Gammon Rd Madison, WI 53719  (608) 819-6865
# 63                  433 S Gammon Rd Madison, WI 53719  (608) 833-7070
# 64              218 S Main St Cottage Grove, WI 53527  (608) 839-5394
# 65            4614 E Washington Ave Madison, WI 53704  (608) 240-0838
# 66            6150 Mineral Point Rd Madison, WI 53705  (608) 236-0607
# 67                  407 W Verona Ave Verona, WI 53593  (608) 845-2304
# 68  9 E Wilson St Hilton Madison Lobby Madison, WI...  (608) 255-5100
# 69                    909 E Broadway Monona, WI 53716  (608) 223-0886
# 70        2825 University Ave Ste 1 Madison, WI 53705  (608) 236-4200
# 71                     114 N Main St Oregon, WI 53575  (608) 835-6238
# 72                 6010 US Hwy 51 McFarland, WI 53558  (608) 838-5888
# 73                  1798 Thierer Rd Madison, WI 53704  (608) 241-5061
# 74             1030 Emerald Ter Sun Prairie, WI 53590  (608) 837-5191
# 75              200 Phillips Blvd Sauk City, WI 53583  (608) 643-2004
# 76               1354 N Bird St Sun Prairie, WI 53590  (608) 837-3311
# 77                  1102 N Main St Edgerton, WI 53534  (608) 884-9866
# 78     1225 Bus Hwy Unit 18-151 Mount Horeb, WI 53572  (608) 437-0806
# 79                  W11602 County Rd V Lodi, WI 53555  (608) 592-3302
# 80     3140 Edmonton Dr Ste 100 Sun Prairie, WI 53590  (608) 834-0263
# 81              550 Water St Prairie Du Sac, WI 53578  (608) 643-0837
# 82                    407 2nd St New Glarus, WI 53574  (608) 527-2900
# 83          23 Glacier Edge Sq Cross Plains, WI 53528  (608) 798-2340
# 84                6220 Nesbitt Rd Fitchburg, WI 53719  (608) 204-7040
# 85                128 E Main St Mount Horeb, WI 53572  (608) 437-3393
# 86                6250 Nesbitt Rd Fitchburg, WI 53719  (608) 663-9390
# 87                1200 Main St Cross Plains, WI 53528  (608) 413-0400
# 88              3318 University Ave Madison, WI 53705  (608) 233-5287
#
#                                            categories
# 0    Diners,Breakfast & Brunch,American (Traditional)
# 1            Bakeries,Breakfast & Brunch,Coffee & Tea
# 2                            Breakfast & Brunch,Cafes
# 3    Breakfast & Brunch,American (Traditional),Donuts
# 4                          Tex-Mex,Breakfast & Brunch
# 5                                  Breakfast & Brunch
# 6                 Breakfast & Brunch,Sandwiches,Cafes
# 7                                  Breakfast & Brunch
# 8                   Cafes,Bakeries,Breakfast & Brunch
# 9       American (New),Sports Bars,Breakfast & Brunch
# 10                                 Breakfast & Brunch
# 11          American (Traditional),Breakfast & Brunch
# 12                  American (New),Breakfast & Brunch
# 13  American (Traditional),Belgian,Breakfast & Brunch
# 14           Burgers,Cocktail Bars,Breakfast & Brunch
# 15         Coffee & Tea,Breakfast & Brunch,Sandwiches
# 16                Italian,Breakfast & Brunch,Desserts
# 17           Breakfast & Brunch,Vegetarian,Sandwiches
# 18         Breakfast & Brunch,American (New),Beer Bar
# 19                                 Breakfast & Brunch
# 20         Breakfast & Brunch,Bakeries,American (New)
# 21              Himalayan/Nepalese,Breakfast & Brunch
# 22             American (New),Breakfast & Brunch,Pubs
# 23                     Breakfast & Brunch,Cafes,Salad
# 24                                 Breakfast & Brunch
# 25               Coffee & Tea,Breakfast & Brunch,Pubs
# 26                           Greek,Breakfast & Brunch
# 27      Breakfast & Brunch,Spanish,Tapas/Small Plates
# 28              Coffee & Tea,Salad,Breakfast & Brunch
# 29                        Breakfast & Brunch,Bakeries
# ..                                                ...
# 59         Coffee & Tea,Breakfast & Brunch,Sandwiches
# 60                          Breakfast & Brunch,Diners
# 61    Breakfast & Brunch,Juice Bars & Smoothies,Cafes
# 62  American (Traditional),Breakfast & Brunch,Sand...
# 63   Diners,Breakfast & Brunch,American (Traditional)
# 64                    Coffee & Tea,Breakfast & Brunch
# 65          Breakfast & Brunch,American (Traditional)
# 66               Bagels,Breakfast & Brunch,Sandwiches
# 67     Bars,American (Traditional),Breakfast & Brunch
# 68           Lounges,Breakfast & Brunch,Cocktail Bars
# 69  American (Traditional),Breakfast & Brunch,Dess...
# 70          Breakfast & Brunch,American (Traditional)
# 71           Coffee & Tea,Bakeries,Breakfast & Brunch
# 72  American (Traditional),Breakfast & Brunch,Sand...
# 73   American (Traditional),Breakfast & Brunch,Diners
# 74   Diners,Breakfast & Brunch,American (Traditional)
# 75                   Bakeries,Breakfast & Brunch,Soup
# 76                    Breakfast & Brunch,Bagels,Delis
# 77  American (Traditional),Breakfast & Brunch,Burgers
# 78                                 Breakfast & Brunch
# 79  American (Traditional),Breakfast & Brunch,Sand...
# 80  Ice Cream & Frozen Yogurt,Coffee & Tea,Breakfa...
# 81                Sandwiches,Cafes,Breakfast & Brunch
# 82                                 Breakfast & Brunch
# 83   American (Traditional),Diners,Breakfast & Brunch
# 84                                 Breakfast & Brunch
# 85                        Bakeries,Breakfast & Brunch
# 86                    Coffee & Tea,Breakfast & Brunch
# 87  Sports Bars,Breakfast & Brunch,American (Tradi...
# 88                    Coffee & Tea,Breakfast & Brunch
#
# [89 rows x 8 columns]

# %%
# extract list of ratings across categories
cat_dict = {}
for val in df.values:
    for cat in val[7].split(","):
        v = np.float32(val[1])
        if cat in cat_dict:
            cat_dict[cat].append(v)
        else:
            cat_dict[cat] = [v]

x_labels = [str(cat) for cat in cat_dict.keys()]

# calculate mean and std deviation for each category
y_avg = [np.mean(cat_dict[cat]) for cat in cat_dict.keys()]
y_std = [np.std(cat_dict[cat]) for cat in cat_dict.keys()]

# define traces and layout for the figure
trace = Bar(
    x = x_labels,
    y = y_avg,
    marker = Marker(color='#E3BA22'),
    error_y = ErrorY(
        type = 'data',
        array = y_std,
        color='#E6842A'
    )
)

layout = Layout(
    title = 'Fig 1. Category vs Ratings Plot',       # set plot title
    yaxis = go.YAxis(
        title = 'Average Rating', # y-axis title
        gridcolor = 'white'
    ),
    xaxis= go.XAxis(
        title = 'Category'  # x-axis title
    ),
    paper_bgcolor = 'rgb(233,233,233)',  # set background color
    plot_bgcolor = 'rgb(233,233,233)',   # set bar color
)

figure=go.Figure(data=[trace], layout=layout)

# display plot on browser
py.iplot(figure, filename='categories-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~shantanusinghal/18.embed" height="525px" width="100%"></iframe>

# %%
rating = df.as_matrix(columns=['rating'])
reviews = df.as_matrix(columns=['reviews'])
price_to = df.as_matrix(columns=['price_to'])
title = df.as_matrix(columns=['title'])

trace = go.Scatter(
    x = reviews,
    y = rating,
    mode = 'markers',
    marker=dict(
        size='10',
        opacity=0.8,
        color = price_to, #set color equal to a variable
        colorscale='Viridis',
        showscale=True,
        colorbar=ColorBar(
            title='Price'
        )
    ),
    text = title
)

axis_style = dict(
    gridcolor='#FFFFFF',  # white grid lines
    zeroline=False        # remove thick zero line
)

layout = go.Layout(
    title='Fig 2. Price Heat Map',
    plot_bgcolor='#f2f2f2',
    xaxis=XAxis(axis_style, title='Number of Reviews'),
    yaxis=YAxis(axis_style, title='Rating')
)

figure=go.Figure(data=[trace], layout=layout)

# Plot and embed in ipython notebook!
py.iplot(figure, filename='basic-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~shantanusinghal/12.embed" height="525px" width="100%"></iframe>
