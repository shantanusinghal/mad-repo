# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import pandas as pd

# set the credentials to access the Plotly API
# plotly.tools.set_credentials_file(username='shantanusinghal2709', api_key='lr1c37zw81')

# read the data collected from web scrapping
df = pd.read_csv('breakfast.csv')
df
# Out:
#     reviews  rating  price_to                       title  price_from  \
# 0        88     4.5        10     Pat O’Malley’s Jet Room           0
# 1       135     5.0        10          4&20 Bakery & Cafe           0
# 2        51     4.5        10                Cottage Cafe           0
# 3       351     3.0        30  Bassett Street Brunch Club          11
# 4       246     3.5        30              Eldorado Grill          11
# 5       253     3.0        10           Mickies Dairy Bar           0
# 6       146     2.5        10                  Crema Cafe           0
# 7       282     2.0        30          Short Stack Eatery          11
# 8       226     4.0        10                 Lazy Jane’s           0
# 9       141     1.5        30               Gates & Brovi          11
# 10      454     1.0        30            Marigold Kitchen          11
# 11       14     4.0        30                        CIRC          11
# ...

# %%
# pull the columns that contribute to the plot dimensions
x_rating = df.as_matrix(columns=['rating'])
s_reviews = df.as_matrix(columns=['reviews'])
y_price_to = df.as_matrix(columns=['price_to'])

# define maps for marker size and color
color_map = {
    '5.0': '#7dce69',
    '4.5': '#759b57',
    '4.0': '#7e9b57',
    '3.5': '#bbc93e',
    '3.0': '#c9bf3e',
    '2.5': '#c9983e',
    '2.0': '#c9773e',
    '1.5': '#c9633e',
    '1.0': '#c9523e',
    '0.5': '#c9443e',
    '0.0': '#ce3939'
}
size_map = {
    '5.0': 144,
    '4.5': 89,
    '4.0': 55,
    '3.5': 34,
    '3.0': 21,
    '2.5': 13,
    '2.0': 8,
    '1.5': 5,
    '1.0': 3,
    '0.5': 2,
    '0.0': 1
}

# %%
from plotly.graph_objs.graph_objs import XAxis, YAxis

# create the trace
trace = go.Scatter(
    x = s_reviews,
    y = y_price_to,
    mode = 'markers+text',
    marker=dict(
        opacity=0.6,
        size = [size_map[str(x[0])]/2 for x in x_rating],
        color = [color_map[str(x[0])] for x in x_rating]
    )
)

axis_style = dict(
    zeroline=False,       # remove thick zero line
    gridcolor='#FFFFFF',  # white grid lines
    ticks='outside',      # draw ticks outside axes 
    ticklen=8,            # tick length
    tickwidth=1.5         #   and width
)

layout = go.Layout(
    title='Breakfast Restaurants in Madison, WI',
    plot_bgcolor='#f2f2f2',
    xaxis=XAxis(axis_style, title='Number of Reviews'),
    yaxis=YAxis(axis_style, title='Max of Price Range in $')
)

figure=go.Figure(data=[trace], layout=layout)

# Plot and embed in ipython notebook!
py.iplot(figure, filename='basic-scatter')

# or plot with: plot_url = py.plot(data, filename='basic-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~shantanusinghal/12.embed" height="525px" width="100%"></iframe>
